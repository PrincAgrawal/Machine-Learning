# %%
# Logistic Distribution
# Logistic Distribution is used to describe growth.

# Used extensively in machine learning in logistic regression, neural networks etc.

# It has three parameters:

# loc - mean, where the peak is. Default 0.

# scale - standard deviation, the flatness of distribution. Default 1.

# size - The shape of the returned array.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import random

# %%
# Draw 2x3 samples from a logistic distribution with mean at 1 and stddev 2.0:

x=random.logistic(loc=1,scale=2,size=(10)) 
print(x)
# Out:
# [-5.47011229  4.16459451  4.71979317 -0.85690972 -2.42317836  1.36483383
#   3.58291185  2.29522355  3.21709187  1.94522132]

# %%
# Visualization of Logistic Distribution/.........

sns.distplot(random.logistic(loc=1,scale=2,size=1000), hist=False)

plt.show()
# Out:
# C:\Users\PRINCE AGRAWAL\AppData\Local\Temp\ipykernel_4404\2091786757.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(loc=1,scale=2,size=1000), hist=False)

# %%
# Difference Between Logistic and Normal Distribution
# Both distributions are near identical, but logistic distribution has more 
#   area under the tails, meaning it represents more possibility of occurrence
#   of an event further away from mean.

# For higher value of scale (standard deviation) the normal and logistic 
#   distributions are near identical apart from the peak.

# %%
sns.distplot(random.normal(scale=2, size=1000), hist=False, label='normal')
sns.distplot(random.logistic(size=1000), hist=False, label='logistic')

plt.show()
# Out:
# C:\Users\PRINCE AGRAWAL\AppData\Local\Temp\ipykernel_4404\1192396331.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(scale=2, size=1000), hist=False, label='normal')
# C:\Users\PRINCE AGRAWAL\AppData\Local\Temp\ipykernel_4404\1192396331.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000), hist=False, label='logistic')
