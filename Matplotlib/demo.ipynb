# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[5,6,7,8]

c=["r","y","g","b"]
plt.bar(x,y,color=c)
plt.show()

# %%
import numpy as np

xpts=np.array([0,6])
ypts=np.array([0,250])
plt.plot(xpts,ypts)
plt.show()
